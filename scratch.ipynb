# %%
import pandas as pd

path = "/Users/jeandavidt/Library/CloudStorage/OneDrive-UniversitéLaval/Université/Doctorat/COVID/Latest Data/wide tables/mtl_01.parquet"

df = pd.read_parquet(path)
for col in df.columns:
    print(col)
# Out:
# CPHD-prov_qc_hlthreg_bas_saint_laurent_cphdID
# CPHD-prov_qc_hlthreg_bas_saint_laurent_notes
# CPHD-prov_qc_hlthreg_bas_saint_laurent_polygonID
# CPHD-prov_qc_hlthreg_bas_saint_laurent_reporterID
# CPHD-prov_qc_hlthreg_capitale_nationale_cphdID
# CPHD-prov_qc_hlthreg_capitale_nationale_notes
# CPHD-prov_qc_hlthreg_capitale_nationale_polygonID
# CPHD-prov_qc_hlthreg_capitale_nationale_reporterID
# CPHD-prov_qc_hlthreg_laval_cphdID
# CPHD-prov_qc_hlthreg_laval_notes
# CPHD-prov_qc_hlthreg_laval_polygonID
# CPHD-prov_qc_hlthreg_laval_reporterID
# CPHD-prov_qc_hlthreg_montreal_conf_report_value
# CPHD-prov_qc_hlthreg_montreal_cphdID
# CPHD-prov_qc_hlthreg_montreal_date
# CPHD-prov_qc_hlthreg_montreal_death_report_value
# CPHD-prov_qc_hlthreg_montreal_hospcen_report_value
# CPHD-prov_qc_hlthreg_montreal_notes
# CPHD-prov_qc_hlthreg_montreal_pctvaccinedose1_report_value
# CPHD-prov_qc_hlthreg_montreal_pctvaccinedose2_report_value
# CPHD-prov_qc_hlthreg_montreal_polygonID
# ...
